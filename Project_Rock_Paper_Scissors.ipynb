# %% [markdown]
# # **Rock Paper Scissors Game Instructions**
#
# Welcome to the Rock Paper Scissors Game! Follow the steps below to play this classic game against the computer.
#
# ## **Instructions:**
#
# 1. **Introduction:**
#    - Upon starting the game, you'll see a welcome message: "WELCOME TO ROCK PAPER SCISSORS GAME".
#
# 2. **Choices:**
#    - You have three choices: Rock, Paper, or Scissors.
#    - Each choice is represented by an index:
#      - 0 for Rock
#      - 1 for Paper
#      - 2 for Scissors
#
# 3. **User Input:**
#    - You will be prompted to enter your choice.
#    - Type `0` for Rock, `1` for Paper, or `2` for Scissors and press Enter.
#
# 4. **Invalid Input:**
#    - If you enter an invalid number (not 0, 1, or 2), you will be asked to enter your choice again until a valid input is provided.
#
# 5. **Display Choices:**
#    - After you make your choice, it will be displayed.
#    - The computer will then randomly select its choice, which will also be displayed.
#
# 6. **Determine the Winner:**
#    - The game will compare your choice with the computer's choice and determine the winner based on the following rules:
#      - Rock (0) beats Scissors (2)
#      - Scissors (2) beats Paper (1)
#      - Paper (1) beats Rock (0)
#    - If both choices are the same, it is a draw.
#    - The result will be displayed, indicating whether you win, lose, or if it’s a draw.
#
# 7. **End of Game:**
#    - The game concludes after displaying the result. You can run the program again to play another round.

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

#Write your code below this line 👇

# %% [markdown]
# # **Solution**

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

#Write your code below this line 👇
choices = [rock, paper, scissors]
print("WELCOME TO ROCK PAPER SCISSORS GAME")
import random
user_choice = 99
while user_choice not in range(3):
    user_choice = int(input("What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.\n"))
    if user_choice not in range(3):
        print("Invalid input")

print("User choice:")
print(choices[user_choice])
computer_choice = random.randint(0, 2)
print("Computer choice:")
print(choices[computer_choice])

if user_choice == computer_choice:
    print("It's a draw")
elif computer_choice == 0 and user_choice == 2:
    print("You lose")
elif computer_choice == 2 and user_choice == 0:
    print("You win")
elif computer_choice > user_choice:
    print("You lose")
elif user_choice > computer_choice:
    print("You win")
# Out:
# WELCOME TO ROCK PAPER SCISSORS GAME
# What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.
# 2
# User choice:
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# Computer choice:
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# You lose
